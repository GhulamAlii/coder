# %%
def addtask(a):
    task["addtask"].append(a)


def view_task():
    i = 1
    for entry in task["addtask"]:
        print (str(i) + ":", entry)
        i += 1


def remove_task(dtask):
    del task["addtask"][dtask]

def edit_list(num,new):
    print("\n")
    view_task()




print("\n-------the TODO App-------")
print("\n---------OPTIONS----------\n")
task={
    "addtask":[],
}

stop=""

                              ####### OPTIONS ##########

while stop != "exit":
    ("\n---------OPTIONS----------\n")
    print("1.Add task\n2.Edit task\n3.View task\n4.Remove task\n5.Exit")
    print("\nwhat do you want to do?")
    print("\n")
    inp1=int(input("type the operation number to perform: "))
    print("\n")
    
                              ####### TAKING USER INPUTE ##########
    
    if inp1<=0 and inp1>=6:
        ("\n---------OPTIONS----------\n")
        print("please write the correct operation number")
        print("\n")
    
                             ####### ADD TASK ##########
    
    elif inp1==1:
        print("\n---------ADD TASK---------\n")
        inp2=input("add your task here")
        addtask(inp2)
        print("\n")
    
                            ####### EDIT TASK ##########
    
    
    elif inp1==2:
        print("\n---------EDIT TASK----------\n")
        l=int(input("type your task number you wish to edit"))
        view_task()
        new=input("now add or edit your task")
        edit_list(l,new)
        print("\n")
                            ####### VIEW TASK ##########
    
    
    elif inp1==3:
        print("\n---------VIEW TASK----------\n")
        print("this is your task list:\n")
        view_task()
        print("\n")
    
                            ####### REMOVE TASK ##########
    
    elif inp1==4:
        print("\n---------REMOVE TASK----------\n")
        print("type your completed task number you wish to delet it in the list\n")
        dl=int(input()) 
        remove_task(dl)
        print("\n")
        print("the task was successfully deleted")
        print("\n")
    
                            ####### EXIT PROGRAM ##########
    
    elif inp1==5:
        print("see you soon")
        stop="exit"
        
                            ####### THANKUU ##########
